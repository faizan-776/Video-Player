# %% [markdown]
# # Video Player 2.0: Colab Test Runner
#
# This notebook is configured to clone the repository and run the AI demo tests.

# %%
# @title Clone Repository
# !git clone https://github.com/faizan-776/Video-Player
# %cd Video-Player

# %%
# @title Install Dependencies
import os
import sys
import subprocess

# 1. Install system dependencies
# !apt-get update -qq && apt-get install -y ffmpeg -qq

# 2. Install Python dependencies
# !pip install fastapi uvicorn pydantic faster-whisper argostranslate scenedetect opencv-python sentence-transformers lancedb pillow ffmpeg-python pyngrok nest_asyncio requests psutil torch

print("\n[OK] Dependencies installed.")

# %% [markdown]
# ## 🧪 Run Tests
#
# Execute the AI demo suite using Colab's resources.

# %%
# @title Run AI Demo Suite (Visual Search, Scenes, Transcription)
import os
os.environ['TRANSFORMERS_VERBOSITY'] = 'error'
os.environ['HF_HUB_DISABLE_SYMLINKS_WARNING'] = '1'
os.environ['PYTHONWARNINGS'] = 'ignore'

# !git pull
# !python tests/test_ai_demo.py 2>&1 | grep -vE "rmdir: failed to remove|HF_TOKEN|CLIPModel LOAD REPORT|Status     \\||-----|UNEXPECTED|Notes:|CLIPImageProcessor|mmco: unref short failure|config\\.json:|Materializing param|OpenVINO detection skipped"
